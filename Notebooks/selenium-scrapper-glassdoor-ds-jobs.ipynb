# %% [markdown]
# # Selenium scrapper
#
# This notebook contains python - Selenium script used to scrape - Glassdoor data science job postings on 15-Jan-24.
#
# Dataset link : [Glassdooor_Data_Science_Jobs_2024](https://www.kaggle.com/datasets/kuralamuthan300/glassdoor-data-science-jobs/data)
#
# Use your local machine to run the scrapping script.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time
from tqdm import tqdm

website = "https://www.glassdoor.com/Job/data-jobs-SRCH_KO0,4.htm"
# path = "C:/Users/xxxxx/Downloads/edgedriver_win64"
job_dataset = pd.DataFrame()

options = webdriver.EdgeOptions()
options.add_argument("--start-minimized")
driver = webdriver.Edge(options=options)

driver.get(website)

# %%
def close_login_popup(driver):
    try:
        # Check for login popup, if present then click CloseButton
        close_login_popup = driver.find_element(By.CLASS_NAME,"CloseButton")
        close_login_popup.click()
        close_login_popup.click()
    except:
        time.sleep(0)

# %%
for i in tqdm(range(0, 25), desc ="Progress"):
    
    close_login_popup(driver)
    
    try:
        time.sleep(3)
        all_matches_button = driver.find_element(By.CSS_SELECTOR, '[data-test="load-more"]')
    except:
        time.sleep(0)
        print("Show more jobs button not found")
    
    close_login_popup(driver)
    all_matches_button.click()
# Out:
# Progress: 100%|██████████| 25/25 [01:22<00:00,  3.28s/it]

# %%
close_login_popup(driver)
all_jobs_list = driver.find_elements(By.XPATH,"//li[@class='JobsList_jobListItem__JBBUV']")

for job in tqdm(all_jobs_list, desc ="Progress"):
    
    job_record = {}
    
    close_login_popup(driver)
    job.click()
    time.sleep(2)
    
    try:
        show_more_button = driver.find_element(By.CLASS_NAME,"JobDetails_showMore__j5Z_h")
        close_login_popup(driver)
        show_more_button.click()
    except:
        time.sleep(0)
    
    job_details_tab = driver.find_element(By.CLASS_NAME,"JobDetails_jobDetailsContainer__sS1W1")
            
    try:
        company = job_details_tab.find_element(By.CLASS_NAME,"EmployerProfile_employerName__Xemli")
        job_record["company"] = company.text
    except:
        job_record["company"] = ""
        
    try:
        job_title = job_details_tab.find_element(By.CLASS_NAME,"JobDetails_jobTitle__Rw_gn")
        job_record["job_title"] = job_title.text
    except:
        job_record["job_title"] = ""
        
    try:
        company_rating = job_details_tab.find_element(By.CLASS_NAME,"EmployerProfile_ratingContainer__N4hxE")
        job_record["company_rating"] = company_rating.text
    except:
        job_record["company_rating"] = ""
        
    try:
        job_description = job_details_tab.find_element(By.CLASS_NAME,"JobDetails_showHidden__trRXQ")
        job_record["job_description"] = job_description.text
    except:
        job_record["job_description"] = ""
        
    try:
        location = job_details_tab.find_element(By.CLASS_NAME,"JobDetails_location__MbnUM")
        job_record["location"] = location.text
    except:
        job_record["location"] = ""
        
    try:
        salary_avg_estimate = job_details_tab.find_element(By.CLASS_NAME,"SalaryEstimate_averageEstimate__xF_7h")
        job_record["salary_avg_estimate"] = salary_avg_estimate.text
    except:
        job_record["salary_avg_estimate"] = ""
        
    try:
        salary_estimate_payperiod = job_details_tab.find_element(By.CLASS_NAME,"SalaryEstimate_payPeriod__oBnsD")
        job_record["salary_estimate_payperiod"] = salary_estimate_payperiod.text
    except:
        job_record["salary_estimate_payperiod"] = ""
        
    try:
        company_overview_values = job_details_tab.find_elements(By.CLASS_NAME,"JobDetails_overviewItemValue__5TqNi")
        job_record.update(
        {"company_size" : company_overview_values[0].text,
        "company_founded" : company_overview_values[1].text,
        "employment_type" : company_overview_values[2].text,
        "industry" : company_overview_values[3].text,
        "sector" : company_overview_values[4].text,
        "revenue" : company_overview_values[5].text
        }
        )
    except:
        job_record.update(
        {"company_size" : "",
        "company_founded" : "",
        "employment_type" : "",
        "industry" : "",
        "sector" : "",
        "revenue" : ""
        }
        )
    
    try:
        company_ratings = job_details_tab.find_elements(By.CLASS_NAME,"JobDetails_ratingScore__Pg9_b")
        job_record["career_opportunities_rating"] = company_ratings[0].text
        job_record["comp_and_benefits_rating"] = company_ratings[1].text
        job_record["culture_and_values_rating"] = company_ratings[2].text
        job_record["senior_management_rating"] = company_ratings[3].text
        job_record["work_life_balance_rating"] = company_ratings[4].text
    except:
        job_record["career_opportunities_rating"] = ""
        job_record["comp_and_benefits_rating"] = ""
        job_record["culture_and_values_rating"] = ""
        job_record["senior_management_rating"] = ""
        job_record["work_life_balance_rating"] = ""
        time.sleep(0)
    
    job_dataset = job_dataset.append(job_record, ignore_index=True)

    print(job_record)
    print("\n")
# Out:
# Progress:   0%|          | 0/780 [00:00<?, ?it/s]C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   0%|          | 1/780 [00:02<33:14,  2.56s/it]
# {'company': 'Reliance Telephone Systems', 'job_title': 'Data And Telephone Technician', 'company_rating': '', 'job_description': 'Data and Telephone Technician\nDuties:\n- Install and Maintain VOIP Telephone Systems\n- Install and Maintain Video Surveillance Systems\n- Install and Configure Networks Including Firewalls, Switches, and Computers\n- Install Wireless Access Points\n- Install Category6 and 6a Data Cable Systems\n- Terminate and Test Fiber Optic Cables\n- Install Paging Systems Including Amplifiers & Speakers\n- Install Door Access Control Systems\nQualifications:\n- Previous experience as a technican is preferred\n- Strong troubleshooting and problem-solving skills\n- Ability to read and interpret technical manuals and schematics\n- Excellent attention to detail and organizational skills\n- Ability to work independently and as part of a team\n-Must have clean driving record and be insurable by the company\nJob Type: Full-time\nPay: $18.00 - $22.00 per hour\nBenefits:\n401(k)\n401(k) matching\nHealth insurance\nHealth savings account\nLife insurance\nPaid time off\nPaid training\nSchedule:\nDay shift\nMonday to Friday\nWork setting:\nIn-person\nApplication Question(s):\nAre you a US Citizen, Green Card holder, or have other legal authorization to work in the US?\nAbility to Commute:\nGrand Forks, ND (Required)\nWork Location: In person', 'location': 'Grand Forks, ND', 'salary_avg_estimate': '$20.00', 'salary_estimate_payperiod': '/hr (est.)', 'company_size': '', 'company_founded': '', 'employment_type': '', 'industry': '', 'sector': '', 'revenue': '', 'career_opportunities_rating': '', 'comp_and_benefits_rating': '', 'culture_and_values_rating': '', 'senior_management_rating': '', 'work_life_balance_rating': ''}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   0%|          | 2/780 [00:04<32:12,  2.48s/it]
# {'company': 'One of our clients', 'job_title': 'Head of Engineering - Data Centre', 'company_rating': '', 'job_description': "Essential Functions:\nWork in partnership with the Construction and Project Managers to ensure delivery and maintenance of all structured cabling and connectivity is on time, within budget, and up to industry leading standards for quality and reliability.\nWork with client field engineering team to monitor progress and quality of installation within all phases of construction and/or operational tasks within the data center(s).\nReview, comprehend and implement work as shown in contract documents. Review drawings and report on discrepancies to foster proactive quality control.\nServe as the technical lead for the construction team on all structured cabling standards, material selection, testing and installation methods in the field. Assist field installation team in resolving technical issues and partner with client’s design and engineer team to support design reviews, BOM reviews, and as-built drawing validations.\nEnsure site as-built design documentation is complete and up-to-date.\nCoordinate with procurement lead as materials subject matter expert (SME) for all materials questions and estimates. Verify all required material types, quantities, cable lengths etc. necessary to complete requested work. Ensure correct mapping of all material counts and characteristics in comparison with construction drawings (general notes) and cable schedules prior to and throughout the duration of the project.\nProvide oversight to the Run Operations team for the detailed turn-up schedule, moves, adds and changes, and set project priorities. Ensure rapid responses to high priority builds and break-fixes.\nSupport development of best practices and initiatives, coordinate SOPs/ SIPs with vendors, and participate in global and regional standards. Assist in developing and/or identifying network cable/rack/cabinet installation processes and standards.\nEnsure crisp oversight and clear communication across multiple platforms with cross-functional partners and vendors. Proactively communicate progress and project risks and initiatives to key stakeholders.\nManage field activities and implement engineering designs.\nCommunicate with clients on site to determine needs and explain complex issues.\nDiagnose construction and/or machinery issues and resolve malfunctions or other crisis when they arise.\nInspect and test material and machinery to ensure proper maintenance of onsite equipment.\nConduct research and studies on site.\nThis position may lead and direct on-site technicians.\nAdditional duties as assigned.\nEducation Requirements:\nBachelor’s Degree in Engineering, Management Information Systems, IT, Computer Science or related field or equivalent, relevant experience.\nExperience Requirements:\n5 years of experience in Structured Cabling, Telecommunications, IT or OSP.\nProven direct experience in fiber optic and structured cabling installation required.\nExperience with outside and inside plant cabling (OSP & ISP) required.\nExperience working in a mission critical environment requiring coordination across multiple disciplines in order to achieve the end goal.\nExperience in OSP, ISP and Run Ops environments preferred.\nExperience leading people and/or project teams preferred.\nExperience reviewing design documents and specifications preferred.\nOther Qualifications, Skills & Certifications:\nProficient with Microsoft Office Suite of tools\nProficient with design and construction software such as Procore, Bluebeam, and BIM360.\nCompetencies\nAbility to analyze, understand and interpret data.\nAbility to think strategically and act tactically.\nAbility to connect with, and influence stakeholders.\nWhat's in it for You?\nJoining our client means you’ll be rewarded with a variety of experiences, development opportunities and exposure to some of the world's most admired companies. In addition to these rewarding experiences, ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   0%|          | 3/780 [00:07<32:34,  2.52s/it]
# {'company': 'Big Sky Managed Care', 'job_title': 'Certified Pharmacy Technician (CPhT) Data entry/Billing', 'company_rating': '2.4', 'job_description': "Our locally owned pharmacy group has an immediate opening for pharmacy Technician to help in our billing/data entry department. We are a dynamic company in high growth mode and are constantly striving to improve ourselves to better support our clients. If you are a self-starter and reliable, you are probably a great fit for our team!\nQualifications:\nMust be a registered Pharmacy Technician in the state of Montana.\nRecent Pharmacy work.\nGood standing with the Board of Pharmacy.\nIV experience is a plus.\nJob Duties:\nAid in the filling of prescriptions from start to finish with automation while ensuring patient safety throughout the dispensing process.\nCommunicate with other health care professionals, patients, family and POA's in a friendly and professional manner.\nMain point of contact for accounts.\nBe able to work with and direct other pharmacy technicians in daily work flow.\nMust be able to show leadership qualities that would represent the companies mission.\nDesire to expand pharmacy services and grow with the company.\nFollow all Montana and Federal pharmacy guidelines.\n**Pre-employment background and drug screening are required**\nBig Sky Managed Care is an Equal Opportunity Employer.\nJob Type: Full-time\nPay: $18.00 - $24.00 per hour\nBenefits:\n401(k) matching\nDental insurance\nHealth insurance\nPaid time off\nVision insurance\nSchedule:\n8 hour shift\nMonday to Friday\nExperience:\nPharmacy technician experience: 1 year (Preferred)\nWork Location: In person", 'location': 'Great Falls, MT', 'salary_avg_estimate': '$21.00', 'salary_estimate_payperiod': '/hr (est.)', 'company_size': '51 to 200 Employees', 'company_founded': '2015', 'employment_type': 'Company - Private', 'industry': 'Pharmaceutical', 'sector': 'Pharmaceutical & Biotechnology', 'revenue': '$5 to $25 million (USD)', 'career_opportunities_rating': '2.4', 'comp_and_benefits_rating': '2.6', 'culture_and_values_rating': '2.1', 'senior_management_rating': '2.6', 'work_life_balance_rating': '2.6'}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|          | 4/780 [00:10<32:35,  2.52s/it]
# {'company': 'HUNTER OIL AND PROPANE', 'job_title': 'Data Entry 2-3 years experience', 'company_rating': '', 'job_description': "```Duties```\n- Prepare and analyze financial statements, including balance sheets, income statements, and cash flow statements\n- Conduct financial forecasting, budgeting, and variance analysis\n- Ensure compliance with GAAP (Generally Accepted Accounting Principles) and company policies\n- Manage the month-end and year-end closing processes\n- Oversee accounts payable and accounts receivable functions\n- Reconcile general ledger accounts and resolve any discrepancies\n- Assist in the preparation of audit schedules and support external auditors\n- Provide financial analysis and recommendations to management for decision-making purposes\n- Collaborate with cross-functional teams to improve financial processes and systems\n- Maintain accurate and up-to-date financial records\n```Experience```\n- Bachelor's degree in Accounting or Finance (CPA preferred)\n- Minimum of 5 years of experience in corporate accounting or related field\n- Strong knowledge of GAAP and financial reporting requirements\n- Proficient in financial report writing and analysis\n- Excellent understanding of debits, credits, and general ledger account reconciliation\n- Experience with financial management software (e.g., Sage) is a plus\n- Demonstrated ability to work independently and meet deadlines\n- Strong attention to detail and accuracy in data analysis\nThis is an excellent opportunity for a Senior Accountant who is looking to take on a challenging role in a dynamic organization. We offer competitive compensation, comprehensive benefits package, and opportunities for professional growth.\nPlease note that only qualified candidates will be contacted for further consideration. Thank you for your interest in joining our team.\nJob Type: Full-time\nPay: From $45,760.00 per year\nBenefits:\nDental insurance\nEmployee discount\nHealth insurance\nRetirement plan\nVision insurance\nSchedule:\n8 hour shift\nDay shift\nMonday to Friday\nWork Location: In person", 'location': 'Sanford, NC', 'salary_avg_estimate': '$45,760', 'salary_estimate_payperiod': '/yr (est.)', 'company_size': '', 'company_founded': '', 'employment_type': '', 'industry': '', 'sector': '', 'revenue': '', 'career_opportunities_rating': '', 'comp_and_benefits_rating': '', 'culture_and_values_rating': '', 'senior_management_rating': '', 'work_life_balance_rating': ''}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|          | 5/780 [00:12<32:31,  2.52s/it]
# {'company': 'Waabigwan Mashkiki', 'job_title': 'Data and Finance Administrator', 'company_rating': '', 'job_description': 'Waabigwan Mashkiki, LLC\nPosition Description\nPosition Code:\nClassification\nNon-Exempt\nSafety Sensitive: Yes\nPosition Title: Data and Finance Administrator\nReports To: CEO and Controller\nDepartment: Waabigwan Mashkiki LLC\nRevision Date: 1/12/2024\nPosition Summary\nWe are actively seeking a talented and forward-thinking Data and Finance Administrator to spearhead the development of predictive models within the cannabis retail space and assist with bookkeeping and marketing tasks. As a key contributor to our team, you will leverage advanced statistical and machine learning techniques to not only analyze historical data but also forecast trends, anticipate market shifts, and optimize retail strategies for our growing cannabis operations. You will also assist the Controller with light bookkeeping duties and work with external marketing teams on ongoing marketing projects.\nEssential Duties & Responsibilities\nPredictive Modeling for Cannabis Retail:\n● Develop and implement advanced statistical and machine learning models to predict cannabis product demand, identify emerging market trends, and inform inventory management strategies.\n● Utilize forecasting algorithms to anticipate market dynamics, enabling proactive decision-making and ensuring optimal stock levels.\nCollaborative Strategy Development:\n● Work closely with cross-functional teams to understand business objectives and integrate predictive models into the development of innovative cannabis retail strategies.\n● Provide actionable insights and recommendations based on predictive analytics to enhance product offerings, pricing strategies, and customer experiences.\nCannabis Customer Segmentation and Personalization:\n● Contribute to the development of sophisticated customer segmentation models to understand the diverse preferences within the cannabis consumer base.\n● Implement personalized retail strategies based on predictive insights to enhance customer satisfaction and drive sales.\nInventory Optimization with Predictive Analytics:\n● Utilize predictive modeling to optimize cannabis product inventory levels, minimizing excess stock and ensuring compliance with regulatory requirements.\n● Develop and refine inventory forecasting models to predict demand fluctuations and maintain optimal stock levels.\nPerformance Monitoring and Reporting:\n● Establish and monitor KPIs specific to predictive modeling outcomes.\n● Generate regular reports and dashboards to communicate the effectiveness of predictive models and their impact on retail performance.\nCompetencies\nUse of Technology – Demonstrates required skills; adapts to new technologies; troubleshoots technological problems; uses technology to increase productivity; keeps technical skills up to date.\nJob Knowledge – Competent in required job skills and knowledge; exhibits ability to learn and apply new skills; keeps abreast of current developments; requires minimal supervision; displays understanding of how job relates to others; uses resources effectively.\nAnalytical – Synthesizes complex or diverse information; collects and researches data; uses intuition and experience to complement data; designs work flows and procedures.\nDesign – Generates creative solutions; translates concepts and information into images; uses feedback to modify designs; applies design principles; demonstrates attention to detail.\nProblem Solving – Identifies and resolves problems in a timely manner; gathers and analyzes information skillfully; develops alternative solutions; works well in group problem solving situations; uses reason even when dealing with emotional topics.\nAdaptability – Adapts to changes in the work environment; manages competing demands; changes approach or method to best fit the situation; able to deal with frequent change, delays, or unexpected events.\nPlanning/Organizing – Prioritizes an ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|          | 6/780 [00:15<32:42,  2.54s/it]
# {'company': 'Ascent LLC.', 'job_title': 'Navy Experience Wanted! Data Center/Critical Facilities Roles -Nationwide', 'company_rating': '3.1', 'job_description': "Ascent is a leading provider of comprehensive solutions for the planning, design, engineering, development and operation of data centres and other mission critical facilities. Headquartered in Saint Louis, MO, Ascent specializes in powerful, efficient and technologically advanced mission critical facilities and offers clients a broad range of delivery models spanning shell & core, build-to-suit, turnkey and outsourced critical systems operations. Founded in 1998, Ascent provides a full spectrum of fast track services that include project programming, design management, facility assessment, development and construction management, commissioning and ongoing maintenance operations. Today, Ascent focuses on providing clients with innovative solutions and services yielding the highest levels of operational autonomy, efficiency and control. Ascent's clients include some of the most demanding mission critical organizations spanning multiple industries, Fortune 500 firms, and service providers.\nTITLE:\nCritical Facilities Technician\nRESPONSIBILITIES:\nAssist in providing on-site field coordination supervision and project management support for the operation of a critical facility.\nAssist in management of mission critical equipment used to operate and maintain facility.\nAssist in management of systems and physical environment integration (life safety, mechanical, plumbing, and power related activities and issues).\nReport discrepancies and trends to the Assistant Critical Facilities Manager, Critical Facilities Manager, operations team and clients.\nAssist in managing preventative and emergency maintenance schedules and procedures for building systems; identify back-up and replacement inventory needs for critical systems.\nAssist in overseeing all maintenance schedules and providers.\nAssist in updates of standard practices consistent for critical facility operations and equipment.\nOversee and coordinate sub-contractors to assure proper installation of equipment and delivery of maintenance services.\nTroubleshoot emergencies, equipment problems, and technical issues, organize and oversee resolutions.\nProvide ongoing technical support, management and oversight of vendors as necessary.\nCompletes daily inspections.\nComplete inspections and maintenance. Scheduled maintenance may include, but is not limited to, monthly, bi-monthly, quarterly, semi-annually, and annual equipment maintenance.\nSelf-perform numerous Electrical/HVAC preventative maintenance activities including but not limited to:\nFilter changes\nGenerator operating tests\nUPS/ATS/STS transfer tests and operation\nProvide field technical support related to redundancy, reliability and maintainability for the facility:\nCurrent needs\nLong-term objectives and strategic planning\nPrimary focus shall be on uptime (99.9999%) and cost saving opportunities\nSupported by Ascent Corporate Engineering group\nAssist in development and implementation of Ascent’s Change Control Program\nMethod of Procedure (MOP), Standard Operating Procedure (SOP), and Emergency Recovery Procedure (ERP) development\nAssist CFM and/or ACFM in administration of onsite Critical Facility Work Rules\nVendor onboarding and familiarization\nSafety inspections and adherence to Ascent safety policies.\nAdministrative policies/procedures\nScope of Work standards\nSpare parts management\nReporting development\nLife Cycle Replacement Strategy\nSupport overall site operation of the facility.\nQualifications\n2+ years of experience as a Critical Facilities Technician or other relevant experience, including Navy or other military experience specializing in electrical or mechanical maintenance operations\nHigh School Diploma or equivalent required\nBS or Technical Degree in Mechanical or Electrical Field or other related field preferred.\nKnowledge of con ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|          | 7/780 [00:17<32:39,  2.54s/it]
# {'company': 'Confidental Company', 'job_title': 'Data Architecture Manager', 'company_rating': '', 'job_description': "We are working on behalf of our client, a large National Insurance Company looking for a Data Insights Manager.\nThis is a full-time position with a hybrid scheme, so the candidate may attend the office in Wilmington, DE at least 3 times a week.\nReporting to Director of Enterprise Data & Analytics, this individual contributor will manage the Business Insights Team & lead the Data Governance team\nJOB FUNCTIONS\nConduct thorough analysis of source data and collaborate closely with the Enterprise Data team.\nEnsure that the development and specification of the company's information systems and products consider business requirements and priorities, with a specific focus on data-related initiatives.\nLead the team in gathering and documenting requirements for all data-related projects, including documenting business processes, defining analytic metrics, and creating data models based on business needs.\nEnsure that requirements for data efforts are comprehensive and accurately represent the specific data needs of each project.\nLead the Analytics Collaboration Team, a cross-departmental group of data analysts, in effectively utilizing Business Intelligence throughout the organization. This includes providing updates on data governance, terminology, emerging technologies, and standards. Additionally, facilitate discussions on best practices, standards, and frameworks related to analytics and data.\nManage the administration and future vision of the BI Tool Framework.\nDemonstrate experience working within an agile development process (Scrum, Kanban, etc.).\nEffectively identify, manage, and mitigate project risks and issues.\nEstablish and advocate for quality and testing best practices, including developing and maintaining monitoring and alerting solutions to ensure data quality and availability.\nAssist business units in understanding data, its availability, and its potential use in analysis to enhance the organization's level of analytics.\nSupport and manage the IT Investment portfolio, as well as handle resource and budget planning and analysis for business projects.\nPerform other duties as assigned.\nJOB REQUIREMENTS\nPossess a Bachelor's degree in a Business or IT related field; however, equivalent experience may be considered in lieu of a degree.\nHave at least 8 years of applicable experience, with a minimum of 6 years of experience in project management processes.\nDemonstrate at least 3 years of leadership experience, preferably in managing PM/BA/BI resources.\nShow a track record of at least 3 years of experience in deploying cloud programs in Data Analytics and AI. This includes expertise in designing, implementing, and operating Lakehouse and Data warehouse architectures using 1st party services on GCP/Azure/AWS.\nDisplay proficiency of at least 3 years in working with Business Intelligence and Data Visualization tools such as Power BI, Tableau, and Looker.\nPossess a strong understanding of Data Analytics/Business Intelligence development processes, including BI, ETL/ELT, Big Data, Data Visualization, and relevant technical platforms/technologies.\nDemonstrate experience in data architecture.\nShowcase proficiency in SQL and database design principles.\nHave experience using agile methodology for software development.\nDemonstrate the ability to manage multiple stakeholders in a collaborative, fast-paced environment.\nPossess a certification in the area of management or information systems (preferred).\nHaving experience with machine learning and AI is a plus.\nJob Type: Full-time\nPay: $165,000.00 per year\nBenefits:\n401(k)\nDental insurance\nHealth insurance\nSchedule:\n8 hour shift\nMonday to Friday\nAbility to commute/relocate:\nWilmington, DE 19801: Reliably commute or planning to relocate before starting work (Preferred)\nEducation:\nBachelor's (Preferred)\nExperience:\nData analytics: 8 ye ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|          | 8/780 [00:20<32:30,  2.53s/it]
# {'company': 'MEI Electrical Contractors & Systems Integrators', 'job_title': "Licensed Electricians/Fire Alarm TQP's/Data-Telecom-Security Technicians", 'company_rating': '', 'job_description': "Job Description\nAbout MEI Electrical Contractors & Systems Integrators:\nMike’s Electric Inc., established in 1991 and now known as MEI Electrical Contractors, has grown into one of the largest electrical contractors in the State of Vermont. In 2014, MEI established MEI Systems Integrators to add security systems installation and monitoring, data, and telecommunications to more fully provide a comprehensive list of services to its customers.\nHeadquartered in Westfield, Vermont, with a branch office in Williston, Vermont, MEI employs more than 80 people and is licensed to provide electrical work and service in Vermont and New Hampshire.\nMEI specializes in commercial, industrial, and residential design/build, electric service upgrades, fire alarm and security system installation and monitoring services, networks, access control, video surveillance, controls, motors, lighting conservation and design, and 24-hour emergency service. MEI provides our clients with efficient, quality work.\nWe are now accepting Applications/Resumes for Licensed Electricians, Fire Alarm TQP's, Data-Telecom-Security Low Voltage Technicians. Join our team by applying online at MEI-VT.com\nQuestions:\nIf you are interested in becoming a member of our team of highly qualified professionals and have questions, give our HR Director a call at 802-988-9678. While we sincerely appreciate all applications, only those candidates selected for interview will be contacted.\nAll qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, disability or veteran status.\nMEI Electrical Contractors System Integrators offer competitive wages, health, dental, and vison insurance, 401K, Vacation, sick, and paid holidays Life Insurance, and STD and LTD. MEI has a strong safety culture and a Sponsored Apprenticeship program.\nJob Type: Full-time\nBenefit Conditions:\nWaiting period may apply\nBenefits offered:\nPaid time off\nParental leave\nHealth insurance\nDental insurance\nHealthcare spending or reimbursement accounts such as HSAs or FSAs\nRetirement benefits or accounts\nEducation assistance or tuition reimbursement\nOther types of insurance\nWork Remotely\nNo\nKey Words; Journeyman, Journeyman Electrician, Electrical Journeyman, Master, Master Electrician, Electrical Master, Fire Alarm Technician, TQP License, Low-Voltage Technician, Data, Security, Type-S License\nJob Type: Full-time\nPay: $20.00 - $40.00 per hour\nBenefits:\n401(k)\nDental insurance\nEmployee assistance program\nEmployee discount\nFlexible spending account\nHealth insurance\nLife insurance\nPaid time off\nProfessional development assistance\nReferral program\nRetirement plan\nTuition reimbursement\nVision insurance\nSchedule:\n10 hour shift\n8 hour shift\nDay shift\nMonday to Friday\nOvertime\nApplication Question(s):\nDo you have reliable transportation?\nExperience:\nElectrical: 1 year (Preferred)\nLicense/Certification:\nElectrical License (Preferred)\nDriver's License (Required)\nShift availability:\nDay Shift (Preferred)\nWork Location: Multiple locations", 'location': 'West Lebanon, NH', 'salary_avg_estimate': '$30.00', 'salary_estimate_payperiod': '/hr (est.)', 'company_size': '', 'company_founded': '', 'employment_type': '', 'industry': '', 'sector': '', 'revenue': '', 'career_opportunities_rating': '', 'comp_and_benefits_rating': '', 'culture_and_values_rating': '', 'senior_management_rating': '', 'work_life_balance_rating': ''}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|          | 9/780 [00:22<32:50,  2.56s/it]
# {'company': 'BendPak', 'job_title': 'SEO Data Specialist', 'company_rating': '2.3', 'job_description': "SUMMARY:\nThe Search Engine Optimization (SEO) Data Specialist will drive search optimization for both web and mobile. This position will own and oversee SEO strategy and be part of the day-to-day execution and maintenance, including keyword research, analysis, portfolio management, and opportunity analysis. They will work closely with the Development, I.T., Brand, Content, Analytics, Technical and Product teams, and key stakeholders to communicate technical details and explain tactics and execution as well as clarifying, interpreting, and implementing, strategic organic search concepts, advancing the channel goals and overall business objectives. The SEO Strategist will be responsible for the ongoing reporting of performance and evolution of the SEO strategy as well as ideation, creation, maintenance of SEO KPI’s and ensuring those KPIs are achieved and align with BendPak’s vision and mission. Employing a data-driven prioritization framework, they are skilled at analyzing metrics to understand and communicate our performance to internal and external teams.\nYour ability to contribute to cross-functional web and mobile initiatives, provide meaningful insights and recommendations to protect or improve rankings, deliver on-page recommendations, review proposed site changes, and perform meaningful analysis in traffic shifts will be instrumental to the success of this role. You must have a solid understanding of the relationship between different digital marketing channels and SEO. You must also have an in-depth knowledge of keyword research, SEO copywriting, and the behaviors of search engines. This role will require a keen understanding of behavioral analytics, as well as a familiarity with absorbing and translating data into a palatable strategy for the team. This position also requires the knowledge of algorithmic evolutions as well as changing nature of social media platforms as they relate to SEO.\nKEY TRAITS AND CHARACTERISTICS:\n· Able to focus on the big picture, while also a lover for the minute details.\n· An excellent communicator and comfortable working with cross-functional teams.\n· A true Problem Solver – can think holistically and present scenarios to solve the problem at hand.\n· Comfortable operating in ambiguity. Apply process where it creates value, and design process where necessary.\n· Effective leadership skills with the ability to work with, influence, and drive the efforts of a cross-functional internal and external teams.\nKEY DUTIES AND RESPONSIBILITIES:\nStrategic Planning\nKeyword Research\nCampaign and Landing Page Optimization\nAnalytics and Tracking\nAlignment with Company Initiatives\nSEO Reporting and Insights\nROI-focused Optimization\nStay Current\nSEO\nWebsite Editing and Content Creation\nTactic level expertise\nSEO & SEM experience within a B2B marketing environment\nMarTech(Marketing Technology) Familiarity\nFocus: Off-Page SEO\nTechnical SEO\nSite Indexing\nResponsible for overseeing strategy and day-to-day execution of local SEO implementation.\nPerform keyword and search trend research to optimize existing content, identify gaps, and uncover new opportunities for improving organic search rankings and driving targeted traffic; educate writers and editors on SEO implementation best practices.\nCollaborate with the marketing team to create and optimize content that aligns with keyword strategies and attracts relevant traffic.\nMonitor and report on keyword rankings, organic traffic, and other key performance indicators to measure the effectiveness of SEO efforts.\nDay-to-day execution of organic SEO campaigns including keyword research, content gap recommendations, strategic optimization of existing content, competitor analysis, and site improvements.\nConduct SWOT competitive analysis to identify strengths, weaknesses, opportunities, and threats for organic search rankings in comparison  ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|▏         | 10/780 [00:25<33:28,  2.61s/it]
# {'company': 'Sallie Mae', 'job_title': 'Manager, Model Validation', 'company_rating': '4.0', 'job_description': "When you join Sallie Mae, you become a champion for all students.\nWe’re on a mission to power confidence as students begin their unique journey. To help them plan their higher education, successfully finish, and prepare for life after school. To help them Start smart. Learn big.\nStudents need guidance navigating this important time in their life. They need someone who acknowledges that their education path is unique. They need a partner willing to evolve and not only meet but surpass their expectations. We’re changing. Because students need a better way.\nWe’re looking for people who are excited to drive this transformation. To break barriers and think of new ways to adapt, help, and create better experiences for students—and for each other.\nThis is where diverse backgrounds, beliefs, and perspectives matter. It’s where you’re empowered to bring your authentic self to work.\nFeeling your best allows you to do your best. Our benefits take care of the whole you—from physical and mental to financial and professional. You’ll get opportunities to further your education and career, support for you and your family (including your pets!), paid time off to volunteer for the things that matter to you, and more.\nWe’re obsessed with impact and making a real difference. For us, that means putting relationships first, asking “why not?” when tackling challenges, and continuously learning new skills.\nCome do more than join something, change something. For students, for future generations, for the future of education.\nWhat You'll Contribute\nThe Manager, Model Risk will be responsible for ensuring the accuracy, integrity, and compliance of our organization's financial models and risk assessment tools.\n\nWhat You'll Do\nMay manage a Model Risk team and provide guidance, support, and mentorship to team members.\nImplement a comprehensive model risk management framework, policies, and procedures to ensure compliance with regulatory requirements and industry best practices.\nOversee the validation and testing of financial models, including model development, data analysis, calibration, and documentation.\nAssess and evaluate the effectiveness and limitations of existing models and identify areas for improvement.\nCollaborate with cross-functional teams to understand business needs and requirements and ensure that models align with organizational objectives.\nConduct periodic model risk assessments, including model governance, validation, and ongoing monitoring, to identify and mitigate potential risks.\nPrepare and present reports on model risk to senior management and regulatory bodies.\nThe above information is intended to describe the general nature and level of work performed by employees assigned to this job; it is not designed to contain or be interpreted as a comprehensive inventory of all duties, responsibilities and qualifications required of employees in this role.\n\nWhat you have\nMinimum education, skills and experience required.\nStrong knowledge of quantitative analysis, statistical techniques, and risk assessment methodologies.\nFamiliarity with regulatory requirements and the ability to interpret and implement them.\nProficiency in programming languages such as SAAS, Python or R, along with experience working with statistical packages.\nExcellent analytical and problem-solving skills, with the ability to evaluate complex financial models and identify potential risks.\nStrong leadership and team management abilities, with a track record of effectively leading and developing teams.\nExceptional written and verbal communication skills, with the ability to present complex information in a clear and concise manner.\nPreferred education, skills, and experience.\nBachelor's degree in finance, mathematics, statistics, economics, or a related field.\n5 years of experience in statistical modeling, model risk management, fi ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   1%|▏         | 11/780 [00:28<33:23,  2.61s/it]
# {'company': 'Recordsforce', 'job_title': 'Document Scanning Specialist - Day Shift (Portsmouth)', 'company_rating': '3.6', 'job_description': "Unleash Your Scanning Superpowers with Us!\nAre you ready to embark on an epic adventure in the world of document scanning? Look no further! Recordsforce, the pioneers of paperless prowess, is on the lookout for a detail-oriented Document Scanning Specialist to join our stellar squad. No experience required – just bring your positive vibes and a willingness to dive into the world of organized chaos!\nRecordsforce has been helping organizations eliminate paper from their business for 20+ years. We are a trusted, family-owned and operated company who encourages our employees to tune into their strengths, while also finding ways to have fun at work each day. We are a crew of creative minds and professional jesters who believe that work can be productive and fun.\nAs our Document Scanning Specialist, you'll be the unsung hero behind the scenes, making sure our clients' documents are scanned, sealed, and delivered with superhero precision. No cape required, but a positive attitude and a strong work ethic are a must!\nWhat you’ll be doing:\nScan documents like a boss using our cutting-edge document scanning software.\nKeep those scanners in check – troubleshoot issues, like paper jams and missed staples.\nBe the guardian of image quality – review digital images for clarity and precision.\nImplement minor job change setups in the imaging software to ensure accuracy when scanning each client's documents.\nUse knowledge of the project requirements to accurately scan.\nExercise strong familiarity of due dates and production time of each job.\nWhat we’re looking for:\nHigh school diploma or GED – check!\nAbility to lift 10-15 pounds – no need for a gym membership!\nWillingness to sit for long periods of time\nComfortable with computers and the Google suite – show us your digital prowess!\nFriendly personality and positive outlook – because scanning should be fun, right?\nStrong sense of personal accountability\nAttention to detail – we don't miss a beat!\nWhat’s in it for you?\nCompensation: 16.25/hour\nMinimum 20 hours a week\n90% paid health insurance - woohoo!\nPaid time off, holidays, and retirement plants – you work hard, you deserve it!\nTeam building and epic offsite events\nReady to be part of the Recordsforce superhero squad? Apply today and let the scanning adventure begin!\nLean more about Recordsforce here:\nwww.recordsforce.com\nhttps://www.facebook.com/recordsforce\nJob Types: Full-time, Part-time\nPay: $16.25 per hour\nBenefits:\nHealth insurance\nPaid time off\nSchedule:\nDay shift\nMonday to Friday\nWeekends as needed\nWork Location: In person", 'location': 'Portsmouth, NH', 'salary_avg_estimate': '$16.25', 'salary_estimate_payperiod': '/hr (est.)', 'company_size': '51 to 200 Employees', 'company_founded': '2001', 'employment_type': 'Company - Private', 'industry': 'Office Supply & Copy Stores', 'sector': 'Retail & Wholesale', 'revenue': '$5 to $25 million (USD)', 'career_opportunities_rating': '3.2', 'comp_and_benefits_rating': '3.4', 'culture_and_values_rating': '3.7', 'senior_management_rating': '3.5', 'work_life_balance_rating': '3.8'}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   2%|▏         | 12/780 [00:30<33:04,  2.58s/it]
# {'company': 'D&D Electrical Contractors, Inc. / Dnet Cabling Technologies', 'job_title': 'Data cabling technician / foreman', 'company_rating': '', 'job_description': "Seeking a low voltage data cabling technician / foreman\n2+ years experience as a lead technician required. Security wiring and electrical metallic tubing experience required. Experience with pre-job layout and installation of alarm cabling via plans / specification or design build. Level III (Fluke) testing, labeling, and manufacturer's warranty / certification. Product certification a plus. Position may also require installing cabling and terminations for audio visual equipment.\nCandidate must be able to follow company and client procedures and protocols, work in occupied workspace and new construction.\nCandidate must prove his experience in real time and verifiable resume. Must also be able to pass a security certification check along with a pre-employment physical and drug screening.\nCandidate must adhere to company and client's safety policies and procedures. OSHA 10 / 30 a plus, but will train.\nMust possess industry standard tools and test equipment applicable to the trade. Continuing training and education reimbursement considered by course.\nMust be flexible with time management and travel within the Greater Boston and surrounding areas. Must be professional, clean cut and client presentable at all times. Take home company vehicle possible after proven abilities and trial period has expired. Competitive compensation based on experience and proven abilities as a lead alarm tech/foreman.\n40+ year company with full benefit package.\nTWO YEARLY BONUS PROGRAMS\nHealth, dental, vision, disability, 401K, PTO and holidays included.\nVisit our website and apply online at\nwww.DandDnet.com\nFax resume 781-932-6290\nCall 781-932-0707\nJob Type: Full-time\nPay: $34.00 - $40.00 per hour\nBenefits:\n401(k)\nDental insurance\nHealth insurance\nHealth savings account\nPaid time off\nRetirement plan\nTuition reimbursement\nVision insurance\nSchedule:\n8 hour shift\nWork Location: Multiple locations", 'location': 'Woburn, MA', 'salary_avg_estimate': '$37.00', 'salary_estimate_payperiod': '/hr (est.)', 'company_size': '', 'company_founded': '', 'employment_type': '', 'industry': '', 'sector': '', 'revenue': '', 'career_opportunities_rating': '', 'comp_and_benefits_rating': '', 'culture_and_values_rating': '', 'senior_management_rating': '', 'work_life_balance_rating': ''}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   2%|▏         | 13/780 [00:33<32:49,  2.57s/it]
# {'company': 'Chiawana Orchards', 'job_title': 'Data Integration Specialist', 'company_rating': '', 'job_description': 'Data Integration Specialist\nColumbia Reach – Chiawana Orchards, a leading apple growing and packing company located in Yakima, Washington, is seeking a highly skilled and motivated individual to join our team as a Data Integration Specialist. This position will play a vital role in ensuring data consistency by working with various databases, APIs, and Business Intelligence tools to integrate and model data effectively.\nResponsibilities:\nWork with different teams to understand data requirements and sources.\nWork with multiple database systems including Oracle and utilizing SQL to extract, transform, and convert data.\nIntegrate data from SOAP/RESTful APIs\nUtilize BI tools such as Microsoft Power BI to develop insightful and actionable reports.\nPerform data manipulation and modeling to enhance data consistency and accuracy.\nQualifications:\nBachelor’s degree in a related field OR equivalent work experience.\nMinimum of 2 years of experience in data integration; 4 or more years preferred.\nStrong proficiency in Oracle, SQL, and a working knowledge of other databases.\nExperience with SOAP APIs for data retrieval and integration.\nProficiency in Business Intelligence tools, with a focus on Microsoft Power BI\nAdditional Skills (Bonus):\nSoftware development\nExperience working for an agricultural company\nFamiliarity with Famous Software (www.famoussoftware.com)\nWhat We Offer:\nCompetitive salary, including paid vacation and sick leave. Salary range is $60,000 - $90,000 depending on experience and qualifications.\nHealth, dental, and vision benefits available\n401(k) plan\nOpportunity for professional development\nA dynamic, fast paced, and collaborative work environment\nThis is a newly created position, and it is anticipated to evolve beyond the initial description. We believe there is a tremendous potential benefit to both our company and the right candidate.\nJob Type: Full-time\nPay: $60,000.00 - $90,000.00 per year\nBenefits:\n401(k)\n401(k) matching\nDental insurance\nHealth insurance\nHealth savings account\nPaid time off\nRetirement plan\nVision insurance\nExperience level:\n2 years\nSchedule:\n8 hour shift\nDay shift\nMonday to Friday\nWork Location: In person', 'location': 'Yakima, WA', 'salary_avg_estimate': '$75,000', 'salary_estimate_payperiod': '/yr (est.)', 'company_size': '', 'company_founded': '', 'employment_type': '', 'industry': '', 'sector': '', 'revenue': '', 'career_opportunities_rating': '', 'comp_and_benefits_rating': '', 'culture_and_values_rating': '', 'senior_management_rating': '', 'work_life_balance_rating': ''}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress:   2%|▏         | 14/780 [00:35<33:11,  2.60s/it]
# ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress: 100%|█████████▉| 777/780 [34:42<00:08,  2.73s/it]
# {'company': 'Paycom Payroll Llc', 'job_title': 'Sr. Data Scientist', 'company_rating': '3.5', 'job_description': "The Staff Data Scientist will translate business problems and opportunities into data science projects. Conduct data analysis and build machine learning models for internal and client-facing applications. Present findings to key stakeholders. Deploy production models. This position will work closely with software development to provide valuable insight to improve business operations.\n\nRESPONSIBILITIES\nMeet with business leaders to understand business challenges and opportunities, and then frame these as data science problems\nIdentify data sources and evaluate suitability for use in analysis and modeling\nManage complex projects by demonstrating scope of data science projects by defining and planning steps\nExtract data from enterprise systems and clean the data for analysis and modeling\nConduct analysis to derive insights from data\nDevelop visualizations of analytics and models for communicating findings\nBuild, test, and validate predictive models\nPut models into production\nPresent insights to key business stakeholders\nMentor junior data scientists\nIdentify opportunities to collect data from new sources or improve existing processes to allow for better analysis and modeling\nImplements new or enhanced software designed to access and handle data more efficiently.\nIdentifies creative solutions to challenging data science problems, determines project requirements and model requirements, and delivers a solution through the lifecycle to the production environment.\nEducation/Certification:\nBachelor's Degree in Computer Science, Data Science, Business Analytics or similar quantitative field\nExperience:\n5+ years in a data scientist role\nSkills/Abilities:\nR and/or Python; SQL; statistical analysis and modeling, including linear and generalized linear models; time series analysis and forecasting; machine learning models such as random forests, XGBoost, and SVM; Spark (in Scala or from R or Python)\nNatural language processing, including topic modeling, intent & entity extraction, and/or building domain-specific language models.\nDemonstrate a high level of autonomy and ability to produce high quality work with minimal guidance.\nDemonstrated ability to communicate data science findings and recommendations to technical and non-technical audiences, including senior and executive leadership.\nExperience monitoring models in production.\nExperience in data mining\nUnderstanding of machine learning\nStrong analytical skills and business acumen\n\nPREFERRED QUALIFICATIONS\nEducation/Certification:\nMaster's degree in Computer Science, Data Science, Business Analytics, or similar quantitative field.\nExperience:\n7+ years in a data scientist role\nSkills/Abilities:\nNeural networks, including CNN and RNN architectures\nBuilding production APIs in Flask, FastAPI or similar frameworks\nExperience deploying models in Docker containers on Kubernetes\nExperience deploying models on-device for iOS and Android\n\nPaycom is an equal opportunity employer and prohibits discrimination and harassment of any kind. Paycom makes employment decisions on the basis of business needs, job requirements, individual qualifications and merit. Paycom wants to have the best available people in every job. Therefore, Paycom does not permit its employees to harass, discriminate or retaliate against other employees or applicants because of race, color, religion, sex, sexual orientation, gender identity, pregnancy, national origin, military and veteran status, age, physical or mental disability, genetic characteristic, reproductive health decisions, family or parental status or any other consideration made unlawful by applicable laws. Equal employment opportunity will be extended to all persons in all aspects of the employer-employee relationship. This policy applies to all terms and conditions of employment, including, but not limited to, hir ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress: 100%|█████████▉| 778/780 [34:44<00:05,  2.74s/it]
# {'company': 'Vagaro', 'job_title': 'Engineering Manager, Machine Learning', 'company_rating': '3.6', 'job_description': "Vagaro is seeking an accomplished and visionary Technical Manager with profound expertise in Machine Learning (ML) and Generative Artificial Intelligence (AI) to lead and drive our ML initiatives. This role will place you at the forefront of designing, developing, and improving ML models with a primary focus on user-centered conversational interfaces. You will work collaboratively with multidisciplinary teams, including Product Managers, Software Engineers, and Designers, to bring innovation to life and deliver a cutting-edge product.\n*Position reports to Pleasanton, CA- Onsite position*\nEmployee Perks & Benefits:\n15 days PTO\n9 company holidays\nReimbursement program using any of Vagaro services.\n401k retirement plan with matching\nHealthcare, dental & vision plans for individuals and families\nLife insurance, supplemental programs\nTuition reimbursement program\nDiscounted tickets program\nDoordash Dash Pass\nOn-site fitness center\nWork/Life & EAP services\nResponsibilities:\nStrategic Leadership: Develop and execute a strategic roadmap for ML and Generative AI applications, aligning technology goals with the company's mission. Define key milestones, timelines, and success metrics to track progress effectively.\nTeam Leadership and Mentorship: Lead and mentor a team of machine learning engineers and data scientists, fostering a collaborative and innovative work environment. Provide guidance, coaching, and support to team members, facilitating their professional growth.\nEnd-to-End Development Lifecycle: Oversee the complete development lifecycle of ML and Generative AI applications, from ideation to deployment and maintenance. Ensure projects are delivered on time and within budget constraints.\nAlgorithm Development: Drive the research, design, and implementation of advanced ML and Generative AI algorithms to enhance model capabilities. Ensure models produce high-quality outputs consistently.\nOptimization and Efficiency: Continuously optimize ML and Generative AI models for efficiency, scalability, and improved performance. Implement strategies for model compression, quantization, and inference acceleration.\nData Management: Supervise data collection, annotation, and preprocessing efforts, ensuring high-quality data pipelines. Implement data governance and privacy best practices.\nPerformance Evaluation: Establish rigorous evaluation protocols and methodologies to assess model performance. Conduct A/B testing and user studies to gather feedback for iterative improvements.\nEthics and Security: Uphold high standards of security and ethics in the development and deployment of ML and Generative AI applications. Collaborate with compliance and legal teams as necessary.\nIntegration and Documentation: Collaborate closely with engineering teams to integrate ML and Generative AI capabilities into various applications. Develop comprehensive documentation for internal and external stakeholders.\nUser-Centric Approach: Collaborate with product managers, designers, and user experience teams to align ML and Generative AI applications with user needs and market requirements. Translate user feedback into actionable improvements.\nMonitoring and Maintenance: Implement monitoring and alerting systems to proactively identify and address issues with Generative AI applications. Ensure regular maintenance, updates, and patches.\nInnovation and Knowledge: Stay informed about the latest advancements in ML and Generative AI. Explore opportunities for innovation and differentiation in Generative AI applications.\nStakeholder Communication: Act as a liaison between technical teams and senior management. Present progress reports, updates, and insights on ML and Generative AI applications' performance and impact.\nQualifications:\nA proven track record of at least 3 years in leading technical teams and delivering complex sof ...
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress: 100%|█████████▉| 779/780 [34:47<00:02,  2.74s/it]
# {'company': 'Stavis Seafoods', 'job_title': 'Data Entry Clerk', 'company_rating': '3.6', 'job_description': 'Stavis Seafoods, a Profand Company is looking to add a Data Entry Clerk to join our Planning and Analysis growing team. The ideal candidate would be detail oriented, organized and data driven with experience working in a fast paced environment.\nResponsibilities:\n- Enter data into computer system accurately and efficiently.\n- Verify and correct data discrepancies or errors.\n- Maintain confidentiality and security of all data.\n- Create spreadsheets to track important customer information, inventory and invoices.\n- Help the Planning Lead to perform data collection and analysis as needed.\n- Transfer data from hard copy to a digital database.\n- Assist with administrative and clerical tasks as assigned\nQualifications:\n- High school diploma or equivalent required.\n- Proven experience in data entry or related field preferred.\n- Proficient in Microsoft Office, particularly Excel\n- Strong attention to detail and accuracy\n- Ability to learn new computer software\nPlease note that this is not a remote position. The Data Entry Clerk will be required to work on-site at our office location.\nJob Type: Full-time\nPay: $18.00 per hour\nExpected hours: 40 per week\nBenefits:\n401(k)\nDental insurance\nHealth insurance\nPaid time off\nVision insurance\nSchedule:\n8 hour shift\nMonday to Friday\nExperience:\nMicrosoft Excel: 2 years (Preferred)\nData Entry: 1 year (Preferred)\nWork Location: In person', 'location': 'Boston, MA', 'salary_avg_estimate': '$18.00', 'salary_estimate_payperiod': '/hr (est.)', 'company_size': '51 to 200 Employees', 'company_founded': '1929', 'employment_type': 'Company - Private', 'industry': 'Food & Beverage Manufacturing', 'sector': 'Manufacturing', 'revenue': '$100 to $500 million (USD)', 'career_opportunities_rating': '3.6', 'comp_and_benefits_rating': '3.9', 'culture_and_values_rating': '3.6', 'senior_management_rating': '3.7', 'work_life_balance_rating': '3.7'}
# C:\Users\Shane\AppData\Local\Temp\ipykernel_8428\2795170194.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   job_dataset = job_dataset.append(job_record, ignore_index=True)
# Progress: 100%|██████████| 780/780 [34:50<00:00,  2.68s/it]
# {'company': 'RESPOND', 'job_title': 'Manager of Contracts & Data', 'company_rating': '4.0', 'job_description': "“I stayed in a violent relationship for years because my children and I had no place else to go.”\nRESPOND has been working to end domestic violence and homelessness in our communities for 50 years! By joining our team as the Manager of Contracts and Data, you will be supporting programs that assist folks experiencing domestic violence find safe, affordable housing and a life free of abuse.\nRESPOND’s three tenets focus on our life changing work, our diverse team, and our commitment to\nlearning.\nThe Manager of Contracts and Data’s Work:\nEach day will be different as you work in a fast-paced back-office setting, as part of a team that serves a diverse population of domestic violence survivors who seek safe, independent housing solutions. Your day may include:\nAttending a bidders’ conference or funders meeting and assessing the appropriateness of the open bid for RESPOND\nCompleting monthly billing for multiple programs across two divisions assuring appropriate contract expenditure\nSpearheading the process of taking a contract submission from idea to execution\nCreating tools for direct service staff to assess eligibility and determining survivors’ eligibility for different programs based on contract requirements.\nTraining staff on proper data collection and outcome measurement (as defined by contracts)\nProviding reports to directors, managers and staffers assisting in understanding trends\nHelping a teammate out! Support a colleague or program in need of an extra set of hands.\nThe team you will be working with:\nMultidisciplinary team of human service workers, business managers, fundraisers, and other professionals\nStaffers who are committed to social services, social justice, and the belief that a life free of abuse and secure housing are human and fundamental rights.\nReporting to the Director of Finance and Administration, you will work daily with the program staff to execute RESPOND’s multiple contracts of $4M+ revenue.\nWhat you will learn, model, or teach:\nHow to use data to provide services community needs.\nAbout the intersection of domestic violence intervention and homelessness prevention.\nBe a part of making your neighborhoods accessible, diverse and a safe place to work, live and play.\nTrauma informed services are the cornerstone of RESPOND services. Program participants are treated with dignity and respect.\nIf you are looking for a career and not just a job, you are in the right place!\nYour Knowledge, Skills, and Attributes:\nProven ability to manage multiple documents in multiple files.\nExcellent organizational and project management skills as they relate to contracts and data.\n3 years’ experience in contract management, preferably in a nonprofit setting\nExcellent communication skills\nAbility to adhere to strict deadlines.\nExpertise with Adobe, Microsoft suite, cloud-based payment processing, and other business applications\nAbility to create, monitor and follow programmatic budgets.\nFamiliarization with data, record keeping, database management and reporting.\nBachelor's degree in business administration, law, or a related field strongly preferred.\nRESPOND Compensation and Benefits include:\nOpportunity to join a new, start-up program and be part of the success from the get-go!\n$70,000-$80,000 a year annual salary paid on a biweekly basis\nAmple accrued paid time off (3 weeks’ vacation, 2 personal days, 12 sick days and 12 holidays)\n401k match up to 3%\nExcellent health and dental insurance that is 80% paid by employer.\nSign-on Bonus of $500 at the five-month anniversary\nRetention Bonus equaling to one week’s pay at the one-year anniversary.\nNo-cost 25k Life insurance policy.\nPre-tax flexible spending and transportation accounts\nAdditional vision, life, and illness policies available at cost to employees\nInterested? Let us know why you want to join the team as the Manager of ...

# %%
job_dataset.head(5)
# Out:
#                       company  \
# 0  Reliance Telephone Systems
# 1          One of our clients
# 2        Big Sky Managed Care
# 3      HUNTER OIL AND PROPANE
# 4          Waabigwan Mashkiki
#
#                                            job_title company_rating  \
# 0                      Data And Telephone Technician
# 1                  Head of Engineering - Data Centre
# 2  Certified Pharmacy Technician (CPhT) Data entr...            2.4
# 3                    Data Entry 2-3 years experience
# 4                     Data and Finance Administrator
#
#                                      job_description         location  \
# 0  Data and Telephone Technician\nDuties:\n- Inst...  Grand Forks, ND
# 1  Essential Functions:\nWork in partnership with...        Pryor, OK
# 2  Our locally owned pharmacy group has an immedi...  Great Falls, MT
# 3  ```Duties```\n- Prepare and analyze financial ...      Sanford, NC
# 4  Waabigwan Mashkiki, LLC\nPosition Description\...     Mahnomen, MN
#
#   salary_avg_estimate salary_estimate_payperiod         company_size  \
# 0              $20.00                /hr (est.)
# 1
# 2              $21.00                /hr (est.)  51 to 200 Employees
# 3             $45,760                /yr (est.)
# 4              $22.50                /hr (est.)
#
#   company_founded    employment_type        industry  \
# 0
# 1
# 2            2015  Company - Private  Pharmaceutical
# 3
# 4
#
#                            sector                  revenue  \
# 0
# 1
# 2  Pharmaceutical & Biotechnology  $5 to $25 million (USD)
# 3
# 4
#
#   career_opportunities_rating comp_and_benefits_rating  \
# 0
# 1
# 2                         2.4                      2.6
# 3
# 4
#
#   culture_and_values_rating senior_management_rating work_life_balance_rating
# 0
# 1
# 2                       2.1                      2.6                      2.6
# 3
# 4

# %%
job_dataset.to_csv('../Data/glassdoor_jobs.csv', index=False)

# %%
# time.sleep(10)
driver.quit()
